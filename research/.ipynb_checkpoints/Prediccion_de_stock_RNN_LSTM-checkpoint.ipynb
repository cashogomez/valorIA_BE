# %% [markdown]
# In this notebook, i tried to predict the open price of Tesla Stock by simple RNN Model and LSTM model.<br>
# Those who want to have detailed info on simple RNN and LSTM, may refer to great post below:<br>
# http://colah.github.io/posts/2015-08-Understanding-LSTMs/

# %% [markdown]
# * [1. Loading Data](#1) <br>
# * [2.Spliting Data as Train and Validation](#2) <br>
# * [3.Creating Train Dataset from Train split](#3) <br>
# * [4.Normalization / Feature Scaling](#4) <br>
# * [5.Creating X_train and y_train from Train data](#5) <br>
# * [6.Creating Simple RNN model](#6) <br>
# * [7.Evaluating Model](#7) <br>
# * [8.Creating Test Dataset from Validation Data](#8) <br>
# * [9.Evaluating with Validation Data](#9) <br>
# * [10.Creating LSTM model](#10) <br>
# * [11.Evaluating LSTM model](#11) <br>
# * [12.Future price prediction](#12) <br>

# %% [markdown]
# <a id="1"></a>
# ## 1.Cargando los datos

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('datos3'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# datos3/TSLA_30min.csv
# datos3/.DS_Store
# datos3/TSLA_15min.csv
# datos3/TSLA.csv
# datos3/TSLA_5min.csv
# datos3/Tesla.csv
# datos3/TSLA_1min.csv

# %%
data2 = pd.read_csv("datos3/TSLA_15min.csv", parse_dates=True)
data2.sort_values('Date', ascending=False, inplace=True)
bool_series = pd.notnull(data2["Date"]) 
data = data2[bool_series]

# %%
data.head()
# Out:
#                Date    Open    High      Low    Close   Volume
# 743  02/10/23 10:00  246.13  249.91  245.820  248.460  7990811
# 742  02/10/23 10:15  248.47  250.78  247.830  248.102  7081601
# 741  02/10/23 10:30  248.15  249.78  247.402  249.080  4807215
# 740  02/10/23 10:45  249.14  251.68  248.680  250.250  5895014
# 739  02/10/23 11:00  250.25  252.15  250.120  251.955  4370893

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1024 entries, 743 to 808
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1024 non-null   object
#  1   Open    1024 non-null   float64
#  2   High    1024 non-null   float64
#  3   Low     1024 non-null   float64
#  4   Close   1024 non-null   float64
#  5   Volume  1024 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 56.0+ KB

# %% [markdown]
# <a id="2"></a>
# ## 2.Spliting Data as Train and Validation

# %%
length_data = len(data)     # rows that data has
split_ratio = 0.7           # %70 train + %30 validation
length_train = round(length_data * split_ratio)  
length_validation = length_data - length_train
print("Data length :", length_data)
print("Train data length :", length_train)
print("Validation data lenth :", length_validation)
# Out:
# Data length : 1024
# Train data length : 717
# Validation data lenth : 307

# %%
train_data = data[:length_train].iloc[:,:2] 
train_data['Date'] = pd.to_datetime(train_data['Date'])  # converting to date time object
train_data
# Out:
#                    Date    Open
# 743 2023-02-10 10:00:00  246.13
# 742 2023-02-10 10:15:00  248.47
# 741 2023-02-10 10:30:00  248.15
# 740 2023-02-10 10:45:00  249.14
# 739 2023-02-10 11:00:00  250.25
# ..                  ...     ...
# 31  2023-10-17 12:00:00  254.96
# 30  2023-10-17 12:15:00  256.78
# 29  2023-10-17 12:30:00  255.98
# 28  2023-10-17 12:45:00  256.74
# 27  2023-10-17 13:00:00  255.91
#
# [717 rows x 2 columns]

# %%
validation_data = data[length_train:].iloc[:,:2]
validation_data['Date'] = pd.to_datetime(validation_data['Date'])  # converting to date time object
validation_data
# Out:
#                    Date     Open
# 26  2023-10-17 13:15:00  254.568
# 25  2023-10-17 13:30:00  254.404
# 24  2023-10-17 13:45:00  254.648
# 23  2023-10-17 14:00:00  254.330
# 22  2023-10-17 14:15:00  254.802
# ..                  ...      ...
# 812 2023-09-29 08:45:00  250.210
# 811 2023-09-29 09:00:00  250.600
# 810 2023-09-29 09:15:00  250.650
# 809 2023-09-29 09:30:00  250.000
# 808 2023-09-29 09:45:00  249.935
#
# [307 rows x 2 columns]

# %% [markdown]
# <a id="3"></a>
# ## 3.Creating Train Dataset from Train split

# %% [markdown]
# * We will get Open column as our dataset
# * Dataset to be converted to array by adding `.values`

# %%
dataset_train = train_data.Open.values
dataset_train.shape
# Out:
# (717,)

# %%
# Change 1d array to 2d array
# Changing shape from (1692,) to (1692,1)
dataset_train = np.reshape(dataset_train, (-1,1))
dataset_train.shape
# Out:
# (717, 1)

# %% [markdown]
# #### <a id="4"></a>
# ## 4.Normalization / Feature Scaling

# %% [markdown]
# * Dataset values will be in between 0 and 1 after scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))


# scaling dataset
dataset_train_scaled = scaler.fit_transform(dataset_train)

dataset_train_scaled.shape
# Out:
# (717, 1)

# %%
plt.subplots(figsize = (15,6))
plt.plot(dataset_train_scaled)
plt.xlabel("Days as 1st, 2nd, 3rd..")
plt.ylabel("Open Price")
plt.show()

# %% [markdown]
# <a id="5"></a>
# ## 5.Creating X_train and y_train from Train data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * We have train data composed of stock open prices over days
# * So, it has 1184 prices corresponding 1184 days
# * My aim is to predict the open price of the next day.
# * I can use a time step of 50 days.
# * I will pick first 50 open prices (0 to 50), 1st 50 price will be in X_train data
# * Then predict the price of 51th day; and 51th price will be in y_train data
# * Again, i will pick prices from 1 to 51, those will be in X_train data
# * Then predict the next days price, 52nd price will be in y_train data

# %%
X_train = []
y_train = []

time_step = 50

for i in range(time_step, length_train):
    X_train.append(dataset_train_scaled[i-time_step:i,0])
    y_train.append(dataset_train_scaled[i,0])
    
# convert list to array
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print("Shape of X_train before reshape :",X_train.shape)
print("Shape of y_train before reshape :",y_train.shape)
# Out:
# Shape of X_train before reshape : (667, 50)
# Shape of y_train before reshape : (667,)

# %% [markdown]
# ## Reshape

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],1))

print("Shape of X_train after reshape :",X_train.shape)
print("Shape of y_train after reshape :",y_train.shape)
# Out:
# Shape of X_train after reshape : (667, 50, 1)
# Shape of y_train after reshape : (667, 1)

# %% [markdown]
# * Shape of X_train : 1134 x 50 x 1
# * That means we have 1134 rows, each row has 50 rows and 1 column
# * Lets check the first row: it has 50 rows (open prices of 49 days)

# %%
X_train[0]
# Out:
# array([[0.13615206],
#        [0.22692009],
#        [0.21450737],
#        [0.25290923],
#        [0.29596587],
#        [0.36152056],
#        [0.44414275],
#        [0.37602793],
#        [0.34228084],
#        [0.36695112],
#        [0.37005431],
#        [0.37587277],
#        [0.30954228],
#        [0.23816912],
#        [0.29868115],
#        [0.25950349],
#        [0.263654  ],
#        [0.27695888],
#        [0.2420481 ],
#        [0.214391  ],
#        [0.23933282],
#        [0.26396431],
#        [0.28510473],
#        [0.31904577],
#        [0.34949573],
#        [0.33048875],
#        [0.34678045],
#        [0.3469744 ],
#        [0.34328937],
#        [0.34367727],
#        [0.32951901],
#        [0.33359193],
#        [0.33378588],
#        [0.32505818],
#        [0.33204034],
#        [0.33591932],
#        [0.33591932],
#        [0.34794414],
#        [0.34445306],
#        [0.34871994],
#        [0.41543832],
#        [0.37005431],
#        [0.3708301 ],
#        [0.38401862],
#        [0.3704422 ],
#        [0.36190846],
#        [0.35686579],
#        [0.35841738],
#        [0.32156711],
#        [0.32893716]])

# %% [markdown]
# * Check the first item in y_train
# * It is the price of 50th day

# %%
y_train[0]
# Out:
# array([0.33165244])

# %% [markdown]
# <a id="6"></a>
# ## 6.Creating RNN model

# %%
# importing libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# initializing the RNN
regressor = Sequential()

# adding first RNN layer and dropout regulatization
regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True, 
              input_shape = (X_train.shape[1],1))
             )

regressor.add(
    Dropout(0.2)
             )


# adding second RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding third RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding fourth RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50)
             )

regressor.add(
    Dropout(0.2)
             )

# adding the output layer
regressor.add(Dense(units = 1))

# compiling RNN
regressor.compile(
    optimizer = "adam", 
    loss = "mean_squared_error",
    metrics = ["accuracy"])

# fitting the RNN
history = regressor.fit(X_train, y_train, epochs = 100, batch_size = 128)
# Out:
# Epoch 1/100
# 2023-10-18 12:04:44.626402: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 6/6 [==============================] - 1s 22ms/step - loss: 0.7079 - accuracy: 0.0030
# Epoch 2/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5578 - accuracy: 0.0015
# Epoch 3/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4880 - accuracy: 0.0030
# Epoch 4/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4190 - accuracy: 0.0030
# Epoch 5/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3720 - accuracy: 0.0000e+00
# Epoch 6/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2986 - accuracy: 0.0015
# Epoch 7/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2843 - accuracy: 0.0030
# Epoch 8/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2903 - accuracy: 0.0015
# Epoch 9/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2907 - accuracy: 0.0030
# Epoch 10/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2595 - accuracy: 0.0030
# Epoch 11/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2442 - accuracy: 0.0030
# Epoch 12/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2352 - accuracy: 0.0030
# Epoch 13/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2376 - accuracy: 0.0015
# Epoch 14/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2337 - accuracy: 0.0015
# Epoch 15/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2205 - accuracy: 0.0015
# Epoch 16/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2343 - accuracy: 0.0030
# Epoch 17/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2057 - accuracy: 0.0015
# Epoch 18/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1938 - accuracy: 0.0030
# Epoch 19/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1714 - accuracy: 0.0015
# Epoch 20/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1652 - accuracy: 0.0015
# Epoch 21/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1446 - accuracy: 0.0030
# Epoch 22/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1629 - accuracy: 0.0015
# Epoch 23/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1522 - accuracy: 0.0030
# Epoch 24/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1608 - accuracy: 0.0015
# Epoch 25/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1462 - accuracy: 0.0015
# Epoch 26/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1513 - accuracy: 0.0015
# Epoch 27/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1392 - accuracy: 0.0030
# Epoch 28/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.1208 - accuracy: 0.0030
# Epoch 29/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1277 - accuracy: 0.0030
# Epoch 30/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1303 - accuracy: 0.0030
# Epoch 31/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1370 - accuracy: 0.0030
# Epoch 32/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1209 - accuracy: 0.0015
# Epoch 33/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1120 - accuracy: 0.0030
# Epoch 34/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1081 - accuracy: 0.0030
# Epoch 35/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1116 - accuracy: 0.0015
# Epoch 36/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0992 - accuracy: 0.0015
# Epoch 37/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.1085 - accuracy: 0.0015
# Epoch 38/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1023 - accuracy: 0.0030
# Epoch 39/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.1051 - accuracy: 0.0015
# Epoch 40/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0955 - accuracy: 0.0015
# Epoch 41/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0936 - accuracy: 0.0015
# Epoch 42/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0811 - accuracy: 0.0030
# Epoch 43/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0943 - accuracy: 0.0030
# Epoch 44/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0879 - accuracy: 0.0015
# Epoch 45/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0796 - accuracy: 0.0000e+00
# Epoch 46/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0791 - accuracy: 0.0030
# Epoch 47/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0826 - accuracy: 0.0030
# Epoch 48/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0750 - accuracy: 0.0030
# Epoch 49/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0735 - accuracy: 0.0030
# Epoch 50/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0734 - accuracy: 0.0030
# Epoch 51/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0700 - accuracy: 0.0030
# Epoch 52/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0704 - accuracy: 0.0030
# Epoch 53/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0655 - accuracy: 0.0030
# Epoch 54/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0683 - accuracy: 0.0030
# Epoch 55/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0728 - accuracy: 0.0030
# Epoch 56/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0581 - accuracy: 0.0030
# Epoch 57/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0644 - accuracy: 0.0030
# Epoch 58/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0616 - accuracy: 0.0030
# Epoch 59/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0617 - accuracy: 0.0030
# Epoch 60/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0586 - accuracy: 0.0030
# Epoch 61/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0593 - accuracy: 0.0030
# Epoch 62/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0602 - accuracy: 0.0015
# Epoch 63/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0559 - accuracy: 0.0030
# Epoch 64/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0484 - accuracy: 0.0030
# Epoch 65/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0547 - accuracy: 0.0030
# Epoch 66/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0554 - accuracy: 0.0015
# Epoch 67/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0523 - accuracy: 0.0030
# Epoch 68/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0509 - accuracy: 0.0030
# Epoch 69/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0498 - accuracy: 0.0030
# Epoch 70/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0460 - accuracy: 0.0000e+00
# Epoch 71/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0469 - accuracy: 0.0030
# Epoch 72/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0454 - accuracy: 0.0030
# Epoch 73/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0453 - accuracy: 0.0015
# Epoch 74/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0458 - accuracy: 0.0030
# Epoch 75/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0424 - accuracy: 0.0015
# Epoch 76/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0375 - accuracy: 0.0030
# Epoch 77/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0385 - accuracy: 0.0030
# Epoch 78/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0391 - accuracy: 0.0030
# Epoch 79/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0397 - accuracy: 0.0030
# Epoch 80/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0439 - accuracy: 0.0030
# Epoch 81/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0407 - accuracy: 0.0030
# Epoch 82/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0399 - accuracy: 0.0030
# Epoch 83/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0401 - accuracy: 0.0030
# Epoch 84/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0370 - accuracy: 0.0030
# Epoch 85/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0369 - accuracy: 0.0015
# Epoch 86/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0372 - accuracy: 0.0030
# Epoch 87/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0309 - accuracy: 0.0030
# Epoch 88/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0300 - accuracy: 0.0030
# Epoch 89/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0280 - accuracy: 0.0030
# Epoch 90/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0298 - accuracy: 0.0030
# Epoch 91/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0326 - accuracy: 0.0015
# Epoch 92/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0324 - accuracy: 0.0015
# Epoch 93/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0331 - accuracy: 0.0030
# Epoch 94/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0295 - accuracy: 0.0030
# Epoch 95/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0295 - accuracy: 0.0030
# Epoch 96/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0319 - accuracy: 0.0030
# Epoch 97/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0321 - accuracy: 0.0030
# Epoch 98/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0297 - accuracy: 0.0030
# Epoch 99/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0302 - accuracy: 0.0030
# Epoch 100/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0311 - accuracy: 0.0015

# %% [markdown]
# <a id="7"></a>
# ## 7.Evaluating Model

# %%
# Losses
history.history["loss"]
# Out:
# [0.7078569531440735,
#  0.5578228831291199,
#  0.4880306124687195,
#  0.4189978241920471,
#  0.37202662229537964,
#  0.2986280024051666,
#  0.2843044698238373,
#  0.2902766466140747,
#  0.29072850942611694,
#  0.25951334834098816,
#  0.24423396587371826,
#  0.23518149554729462,
#  0.23758511245250702,
#  0.23374053835868835,
#  0.22053374350070953,
#  0.23433807492256165,
#  0.20566222071647644,
#  0.19376617670059204,
#  0.1714271754026413,
#  0.16519369184970856,
#  0.14464063942432404,
#  0.16294562816619873,
#  0.15222899615764618,
#  0.16075760126113892,
#  0.14615114033222198,
#  0.15125522017478943,
#  0.13924351334571838,
#  0.12077179551124573,
#  0.1277448832988739,
#  0.13026592135429382,
#  0.13704191148281097,
#  0.12088241428136826,
#  0.11201384663581848,
#  0.10810336470603943,
#  0.11160872131586075,
#  0.0991596207022667,
#  0.10847395658493042,
#  0.10226147621870041,
#  0.10510050505399704,
#  0.09552916139364243,
#  0.09362689405679703,
#  0.08106636255979538,
#  0.09433213621377945,
#  0.08789655566215515,
#  0.07963839173316956,
#  0.0790754184126854,
#  0.08257069438695908,
#  0.07497961074113846,
#  0.07350937277078629,
#  0.07337532937526703,
#  0.06999682635068893,
#  0.07038969546556473,
#  0.06554564833641052,
#  0.06832557171583176,
#  0.07277204096317291,
#  0.05805820971727371,
#  0.06435450166463852,
#  0.06163633242249489,
#  0.06167391315102577,
#  0.05856941640377045,
#  0.059284891933202744,
#  0.060210634022951126,
#  0.05593465268611908,
#  0.04842487722635269,
#  0.05469903722405434,
#  0.05536580830812454,
#  0.05227535218000412,
#  0.05088159814476967,
#  0.049806930124759674,
#  0.04595061391592026,
#  0.04693989455699921,
#  0.045385438948869705,
#  0.045252811163663864,
#  0.04575874283909798,
#  0.04240851104259491,
#  0.03750891983509064,
#  0.038538601249456406,
#  0.03914425149559975,
#  0.039747342467308044,
#  0.04391423612833023,
#  0.04067010059952736,
#  0.03989412263035774,
#  0.040100086480379105,
#  0.03699631989002228,
#  0.03691251948475838,
#  0.03724764287471771,
#  0.03094426915049553,
#  0.02996107004582882,
#  0.028008585795760155,
#  0.029834117740392685,
#  0.03261670097708702,
#  0.03237593546509743,
#  0.033083051443099976,
#  0.02948416769504547,
#  0.029475850984454155,
#  0.031911276280879974,
#  0.03210260719060898,
#  0.029692454263567924,
#  0.03017597086727619,
#  0.031131261959671974]

# %%
# Plotting Loss vs Epochs
plt.figure(figsize =(10,7))
plt.plot(history.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("Simple RNN model, Loss vs Epoch")
plt.show()

# %%
# Plotting Accuracy vs Epochs
plt.figure(figsize =(10,5))
plt.plot(history.history["accuracy"])
plt.xlabel("Epochs")
plt.ylabel("Accuracies")
plt.title("Simple RNN model, Accuracy vs Epoch")
plt.show()

# %% [markdown]
# ## Model predictions for train data

# %%
y_pred = regressor.predict(X_train)  # predictions
y_pred = scaler.inverse_transform(y_pred) # scaling back from 0-1 to original
y_pred.shape
# Out:
# 21/21 [==============================] - 0s 3ms/step
# (667, 1)

# %%
y_train = scaler.inverse_transform(y_train) # scaling back from 0-1 to original
y_train.shape
# Out:
# (667, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred, color = "b", label = "y_pred" )
plt.plot(y_train, color = "g", label = "y_train")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Predictions with input X_train vs y_train")
plt.legend()
plt.show()

# %% [markdown]
# <a id="8"></a>
# ## 8.Creando el conjunto de datos de prueba desde los datos de  Validación

# %% [markdown]
# ### Converting array and scaling

# %%
dataset_validation = validation_data.Open.values  # getting "open" column and converting to array
dataset_validation = np.reshape(dataset_validation, (-1,1))  # converting 1D to 2D array
scaled_dataset_validation =  scaler.fit_transform(dataset_validation)  # scaling open values to between 0 and 1
print("Shape of scaled validation dataset :",scaled_dataset_validation.shape)
# Out:
# Shape of scaled validation dataset : (307, 1)

# %% [markdown]
# ### Creating X_test and y_test

# %%
# Creating X_test and y_test
X_test = []
y_test = []

for i in range(time_step, length_validation):
    X_test.append(scaled_dataset_validation[i-time_step:i,0])
    y_test.append(scaled_dataset_validation[i,0])

# %% [markdown]
# ### Converting to array

# %%
# Converting to array
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
print("Shape of X_test before reshape :",X_test.shape)
print("Shape of y_test before reshape :",y_test.shape)
# Out:
# Shape of X_test before reshape : (257, 50)
# Shape of y_test before reshape : (257,)

# %% [markdown]
# ### Reshape

# %%
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))  # reshape to 3D array
y_test = np.reshape(y_test, (-1,1))  # reshape to 2D array

# %%
print("Shape of X_test after reshape :",X_test.shape)
print("Shape of y_test after reshape :",y_test.shape)
# Out:
# Shape of X_test after reshape : (257, 50, 1)
# Shape of y_test after reshape : (257, 1)

# %% [markdown]
# <a id="9"></a>
# ## 9.Evaluando con los datos de validación

# %%
# predictions with X_test data
y_pred_of_test = regressor.predict(X_test)
# scaling back from 0-1 to original
y_pred_of_test = scaler.inverse_transform(y_pred_of_test) 
print("Shape of y_pred_of_test :",y_pred_of_test.shape)
# Out:
# 9/9 [==============================] - 0s 3ms/step
# Shape of y_pred_of_test : (257, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred_of_test, label = "y_pred_of_test", c = "orange")
plt.plot(scaler.inverse_transform(y_test), label = "y_test", c = "g")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Prediction with input X_test vs y_test")
plt.legend()
plt.show()

# %%
# Visualisation
plt.subplots(figsize =(30,12))
plt.plot(train_data.Date, train_data.Open, label = "train_data", color = "b")
plt.plot(validation_data.Date, validation_data.Open, label = "validation_data", color = "g")
plt.plot(train_data.Date.iloc[time_step:], y_pred, label = "y_pred", color = "r")
plt.plot(validation_data.Date.iloc[time_step:], y_pred_of_test, label = "y_pred_of_test", color = "orange")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Train-Validation-Prediction")
plt.legend()
plt.show()

# %% [markdown]
# <a id="10"></a>
# ## 10.Creando el Modelo LSTM

# %%
y_train = scaler.fit_transform(y_train)

# %%
from keras.layers import LSTM

model_lstm = Sequential()
model_lstm.add(
    LSTM(64,return_sequences=True,input_shape = (X_train.shape[1],1))) #64 lstm neuron block
model_lstm.add(
    LSTM(64, return_sequences= False))
model_lstm.add(Dense(32))
model_lstm.add(Dense(1))
model_lstm.compile(loss = "mean_squared_error", optimizer = "adam", metrics = ["accuracy"])
history2 = model_lstm.fit(X_train, y_train, epochs = 40, batch_size = 40)
# Out:
# Epoch 1/40
# 2023-10-18 12:05:01.231324: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-18 12:05:01.231845: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-18 12:05:01.232479: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-10-18 12:05:01.295158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-18 12:05:01.295622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-18 12:05:01.296137: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-10-18 12:05:01.394788: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-18 12:05:01.395370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-18 12:05:01.395945: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-10-18 12:05:01.467587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-18 12:05:01.468432: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-18 12:05:01.468959: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-10-18 12:05:01.750855: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-18 12:05:01.751610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-18 12:05:01.752097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-10-18 12:05:01.821965: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-18 12:05:01.822534: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-18 12:05:01.823041: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 17/17 [==============================] - 1s 20ms/step - loss: 0.0970 - accuracy: 0.0030
# Epoch 2/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0190 - accuracy: 0.0030
# Epoch 3/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0142 - accuracy: 0.0030
# Epoch 4/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0122 - accuracy: 0.0030
# Epoch 5/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0111 - accuracy: 0.0030
# Epoch 6/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0101 - accuracy: 0.0030
# Epoch 7/40
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0092 - accuracy: 0.0030
# Epoch 8/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0086 - accuracy: 0.0030
# Epoch 9/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0081 - accuracy: 0.0030
# Epoch 10/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0079 - accuracy: 0.0030
# Epoch 11/40
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0071 - accuracy: 0.0030
# Epoch 12/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0071 - accuracy: 0.0030
# Epoch 13/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0067 - accuracy: 0.0030
# Epoch 14/40
# 17/17 [==============================] - 0s 22ms/step - loss: 0.0064 - accuracy: 0.0030
# Epoch 15/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0062 - accuracy: 0.0030
# Epoch 16/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0059 - accuracy: 0.0030
# Epoch 17/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0057 - accuracy: 0.0030
# Epoch 18/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0057 - accuracy: 0.0030
# Epoch 19/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0054 - accuracy: 0.0030
# Epoch 20/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0054 - accuracy: 0.0030
# Epoch 21/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0048 - accuracy: 0.0030
# Epoch 22/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0048 - accuracy: 0.0030
# Epoch 23/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0045 - accuracy: 0.0030
# Epoch 24/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0046 - accuracy: 0.0030
# Epoch 25/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0048 - accuracy: 0.0030
# Epoch 26/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0043 - accuracy: 0.0030
# Epoch 27/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0040 - accuracy: 0.0030
# Epoch 28/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0038 - accuracy: 0.0030
# Epoch 29/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0039 - accuracy: 0.0030
# Epoch 30/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0037 - accuracy: 0.0030
# Epoch 31/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0036 - accuracy: 0.0030
# Epoch 32/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0035 - accuracy: 0.0030
# Epoch 33/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0034 - accuracy: 0.0030
# Epoch 34/40
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0036 - accuracy: 0.0030
# Epoch 35/40
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0037 - accuracy: 0.0030
# Epoch 36/40
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0033 - accuracy: 0.0030
# Epoch 37/40
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0036 - accuracy: 0.0030
# Epoch 38/40
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0032 - accuracy: 0.0030
# Epoch 39/40
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0031 - accuracy: 0.0030
# Epoch 40/40
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0032 - accuracy: 0.0030

# %% [markdown]
# <a id="11"></a>
# ## 11.Evaluando el modelo LSTM

# %%
plt.figure(figsize =(10,5))
plt.plot(history2.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("LSTM model, Accuracy vs Epoch")
plt.show()

# %%
plt.subplots(figsize =(30,12))
plt.plot(scaler.inverse_transform(model_lstm.predict(X_test)), label = "y_pred_of_test", c = "orange" )
plt.plot(scaler.inverse_transform(y_test), label = "y_test", color = "g")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("LSTM model, Predictions with input X_test vs y_test")
plt.legend()
plt.show()
# Out:
# 9/9 [==============================] - 0s 4ms/step
# 2023-10-18 12:05:16.250510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-18 12:05:16.251255: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-18 12:05:16.251719: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-10-18 12:05:16.326566: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-10-18 12:05:16.327092: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-10-18 12:05:16.327575: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %% [markdown]
# <a id="12"></a>
# ## 12.Predicción futura

# %% [markdown]
# * Which day is the last day in our data?

# %%
data.iloc[-1]
# Out:
# Date      29/09/23 9:45
# Open            249.935
# High              253.5
# Low               249.9
# Close            253.24
# Volume          8961574
# Name: 808, dtype: object

# %% [markdown]
# * We can predict the open price for the day after 3/17/2017--> for  3/18/2017.
# * We will use last 50 days Open price as input of our model for this prediction
# * Let us prepare it:

# %%
X_input = data.iloc[-time_step:].Open.values               # getting last 50 rows and converting to array
X_input = scaler.fit_transform(X_input.reshape(-1,1))      # converting to 2D array and scaling
X_input = np.reshape(X_input, (1,50,1))                    # reshaping : converting to 3D array
print("Shape of X_input :", X_input.shape)
X_input
# Out:
# Shape of X_input : (1, 50, 1)
# array([[[0.61772152],
#         [0.44050633],
#         [0.        ],
#         [0.18227848],
#         [0.34683544],
#         [0.68506329],
#         [0.91139241],
#         [0.83772152],
#         [0.83240506],
#         [0.79291139],
#         [0.88860759],
#         [0.94936709],
#         [0.90886076],
#         [0.84810127],
#         [0.81518987],
#         [0.81772152],
#         [0.8       ],
#         [0.81265823],
#         [0.81012658],
#         [0.80253165],
#         [0.81012658],
#         [0.78227848],
#         [0.78987342],
#         [0.79746835],
#         [0.76202532],
#         [0.75443038],
#         [0.69113924],
#         [0.81518987],
#         [1.        ],
#         [0.90379747],
#         [0.75189873],
#         [0.89367089],
#         [0.89113924],
#         [0.85822785],
#         [0.91139241],
#         [0.89113924],
#         [0.88101266],
#         [0.87594937],
#         [0.76962025],
#         [0.81772152],
#         [0.67088608],
#         [0.63797468],
#         [0.91898734],
#         [0.7164557 ],
#         [0.63037975],
#         [0.87088608],
#         [0.96962025],
#         [0.98227848],
#         [0.81772152],
#         [0.80126582]]])

# %%
simple_RNN_prediction = scaler.inverse_transform(regressor.predict(X_input))
LSTM_prediction = scaler.inverse_transform(model_lstm.predict(X_input))
print("Simple RNN, Open price prediction:", simple_RNN_prediction[0,0])
print("LSTM prediction, Open price prediction:", LSTM_prediction[0,0])
# Out:
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# Simple RNN, Open price prediction: 250.26692
# LSTM prediction, Open price prediction: 249.86006
